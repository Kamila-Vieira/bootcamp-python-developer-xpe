# %% [markdown]
# Erros de Sintaxe
#
# Um erro de sintaxe ocorre quando o desenvolvedor escreve uma instrução utilizando a sintaxe incorretamente:

# %%
x = 3 
y = 5 
print x + y
# Out:
#   File "<ipython-input-1-4638c52ed85d>", line 3
#     print x + y
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(x + y)?

# %% [markdown]
# Erros em Tempo de Execução
#
# Surgem quando o Python não consegue executar a instrução devido à alguma inconsistência:

# %%
# utilização de uma variável inexistente (não definida)
# x = 0 
# print(xx)

# declaração incorreta da variável dia, como Dia

# dia = 'Segunda Feira' 
# print(Dia)

# Divisão de um número por zero
25 / x
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-4667bfa2e8b0> in <module>
#       9
#      10 # Divisão de um número por zero
# ---> 11 25 / x
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Erros Lógicos

# %%
x = 5.0 
y = 7.0 
z = 12.0 
media = x + y + z / 3 
print(media)
# Out:
# 16.0

# %% [markdown]
# Observe que, por não ter nenhuma regra violada, o interpretador foi capaz de executar todas as instruções e retornar 16.0, que por usa vez não é a média dos números 5.0, 7.0 e 12.0. A resposta correta deveria ser 8.0. Este erro é devido à ordem de execução das operações. Primeiramente, o valor de z foi dividido por três, resultando em 4.0 e em seguida somado com x e y: media = 5.0 + 7.0 + 4.0 => 16.0. O correto seria indicar a precedência das somas, utilizando parênteses, e em seguida dividir por 3:

# %%
media = (x + y + z) / 3 
print(media)
# Out:
# 8.0
