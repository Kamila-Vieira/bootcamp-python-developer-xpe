# %% [markdown]
# Conjuntos

# %%
# Criação de um conjunto homogêneo 
c1 = {3, 0, 1, 4, 2, 3} 
print(c1)
# Out:
# {0, 1, 2, 3, 4}

# %%
# Criação do mesmo conjunto, porém com uma ordenação diferente dos itens 
c2 = {2, 1, 4, 3, 0}
print(c2)
# Out:
# {0, 1, 2, 3, 4}

# %%
c1 == c2
# Out:
# True

# %% [markdown]
# **Os elementos nunca se repetem e os elementos são sempre ordenado, essa ordenação também respoeita o tipo**
#
# ````
#     Nome == 0
#     True == 1
# ````

# %%
# Conjunto heterogêneo 
c3 = {2, 'a', 5.44, True, None} 
print(c3)
# Out:
# {None, True, 2, 5.44, 'a'}

# %% [markdown]
# **Os conjuntos não possuem uma maneira direta de acessar os seus elementos.** Isso pode não fazer sentido agora, mas o tipo set é uma estrutura projetada para não fornecer acesso aos elementos, e sim para representar os dados em forma de conjuntos e oferecer suas operações matemáticas tradicionais.
#
# ![image.png](data:image/png;base64,...)

# %%
# Criação dos conjuntos A e B 
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7, 8}
print('A:', A) 
print('B:', B)
# Out:
# A: {1, 2, 3, 4, 5}
# B: {4, 5, 6, 7, 8}

# %%
# Operação de União: (A ∪ B) ===> concatena os valores dos conjuntos
print('A | B =>', A | B) 
print('A.union(B) =>', A.union(B))
# Out:
# A | B => {1, 2, 3, 4, 5, 6, 7, 8}
# A.union(B) => {1, 2, 3, 4, 5, 6, 7, 8}

# %%
# Operação de Interseção: (A ∩ B) ===> Apenas itens que estão em ambos
print('A & B =>', A & B) 
print('A.intersection(B) =>', A.intersection(B))
# Out:
# A & B => {4, 5}
# A.intersection(B) => {4, 5}

# %%
# Operação de Diferença: (A - B) ===> Valores de A que não estão contidos em B
print('A - B =>', A - B) 
print('A.difference(B) =>', A.difference(B)) 

# Operação de Diferença: (B - A) ===> Valores de B que não estão contidos em A
print('B - A =>', B - A) 
print('B.difference(A) =>', B.difference(A))
# Out:
# A - B => {1, 2, 3}
# A.difference(B) => {1, 2, 3}
# B - A => {8, 6, 7}
# B.difference(A) => {8, 6, 7}

# %% [markdown]
# Operações em conjuntos

# %%
# Criação dos conjuntos
c1 = {1, 2, 3, 4, 5} 
c2 = {4, 5} 
c3 = {91, 92, 93}

# %%
# Adiciona um elemento ao conjunto 
c1.add(6) 
print(c1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# Adiciona os elementos de uma sequência iterável 
c1.update([2, 4, 6, 8]) 
print(c1)
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
# Descarta um elemento do conjunto, 
c1.discard(8) 
print(c1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# Diferentemente do set.remove(), o discard não gera um erro 
# se o elmento a ser removido não existir
c1.discard(99) 
print(c1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# Verifica se os conjuntos são disjuntos, ou seja, 
# se não possuem nenhum elemento em comum 
print(c1.isdisjoint(c2)) 
print(c1.isdisjoint(c3))
print(c2.isdisjoint(c3))
# Out:
# False
# True
# True

# %%
# Verifica se o conjunto é subconjunto de outro 
print(c1.issubset(c2)) 
print(c2.issubset(c1))
# Out:
# False
# True

# %%
# Verifica se o conjunto contém outro conjunto (superset) 
print(c1.issuperset(c2))
print(c2.issuperset(c1))
# Out:
# True
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 1. Criar uma relação com todos os alunos da escola, sem repetições;
# 2. Identificar os alunos que estão matriculados em pelo menos duas turmas para oferecermos um desconto;

# %% [markdown]
# Resolução com Listas:

# %%
# Criação das listas de alunos das turmas 
ING = ['Gabriel', 'Caio', 'Maria', 'Ana', 'Juliano', 'Flávia', 'Rubens', 'Bruna'] 
ESP = ['Caio', 'Artur', 'Beatriz', 'Carolina', 'Maria', 'Juliano', 'Bruna', 'Rui'] 
FRA = ['Pedro', 'Bruna', 'Paula', 'Tiago', 'Maria', 'Flávia', 'Rui', 'Carolina']

# Concatenação de todas as listas de alunos 
ALL = ING + ESP + FRA

# Ordenação para melhor visualização 
ALL.sort() 
# Exibição do resultado 
print('Relação de todos os alunos da escola:') 
print(ALL)
# Out:
# Relação de todos os alunos da escola:
# ['Ana', 'Artur', 'Beatriz', 'Bruna', 'Bruna', 'Bruna', 'Caio', 'Caio', 'Carolina', 'Carolina', 'Flávia', 'Flávia', 'Gabriel', 'Juliano', 'Juliano', 'Maria', 'Maria', 'Maria', 'Paula', 'Pedro', 'Rubens', 'Rui', 'Rui', 'Tiago']

# %% [markdown]
# Resolução com Conjuntos:

# %%
# Criação das listas de alunos das turmas 
CING = {'Gabriel', 'Caio', 'Maria', 'Ana', 'Juliano', 'Flávia', 'Rubens', 'Bruna'}
CESP = {'Caio', 'Artur', 'Beatriz', 'Carolina', 'Maria', 'Juliano', 'Bruna', 'Rui' }
CFRA =  { 'Pedro', 'Bruna', 'Paula', 'Tiago', 'Maria', 'Flávia', 'Rui', 'Carolina'}

# Concatenação de todas as listas de alunos 
CALL = CING | CESP | CFRA

# O Conjunto já é automáticamente ordenado

# Exibição do resultado 
print('Relação de todos os alunos da escola:') 
print(CALL)
# Out:
# Relação de todos os alunos da escola:
# {'Maria', 'Rui', 'Juliano', 'Ana', 'Caio', 'Artur', 'Paula', 'Pedro', 'Flávia', 'Tiago', 'Carolina', 'Rubens', 'Beatriz', 'Bruna', 'Gabriel'}

# %% [markdown]
# Verificar os alunos que terão desconto (Que estão em mais de uma turma)

# %%
I_ING_ESP = CING & CESP
I_ING_ESP
# Out:
# {'Bruna', 'Caio', 'Juliano', 'Maria'}

# %%
I_ING_FRA = CING & CFRA
I_ING_FRA
# Out:
# {'Bruna', 'Flávia', 'Maria'}

# %%
I_ESP_FRA = CESP & CFRA
I_ESP_FRA
# Out:
# {'Bruna', 'Carolina', 'Maria', 'Rui'}

# %%
# 1 – Interseção entre os pares de turmas: (ING & ESP), (ING & FRA) e (ESP & FRA)
# 2 – Calcula a união das interseções 
ALUNOS_DESCONTO = I_ING_ESP | I_ING_FRA | I_ESP_FRA # OU (CING & CESP) | (CING & CFRA) | (CESP & CFRA) 
# Exibição do resultado 
print('Relação dos alunos com desconto:') 
print(ALUNOS_DESCONTO)
# Out:
# Relação dos alunos com desconto:
# {'Flávia', 'Maria', 'Rui', 'Juliano', 'Carolina', 'Caio', 'Bruna'}

# %%
I_ING_ESP_FRA = CING & CESP & CFRA
I_ING_ESP_FRA
# Out:
# {'Bruna', 'Maria'}

# %%
print('Relação dos alunos matriculados em todas as turmas:') 
print(I_ING_ESP_FRA)
# Out:
# Relação dos alunos matriculados em todas as turmas:
# {'Maria', 'Bruna'}
