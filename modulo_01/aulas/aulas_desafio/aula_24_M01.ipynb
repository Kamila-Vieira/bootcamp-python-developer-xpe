# %% [markdown]
# Escrita de Arquivos

# %%
arquivo = open('arquivos_aulas/cidades.txt', 'a') 
arquivo.write('RJ; São Gonçalo; 1031903\n') 
arquivo.close()

# %%
linhas = [ 
    'AL; Maceió; 1005319\n', 
    'RJ; Duque de Caxias; 878402\n', 
    'RN; Natal; 862044\n', 
    'MS; Campo Grande; 843120\n' 
] 

arquivo = open('arquivos_aulas/cidades.txt', 'a') 
arquivo.writelines(linhas) 
arquivo.close()
