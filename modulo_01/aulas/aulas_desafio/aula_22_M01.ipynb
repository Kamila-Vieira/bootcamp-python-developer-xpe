# %% [markdown]
# Manipulação de Arquivos

# %% [markdown]
# *Criação, Abertura e Fechamento de Arquivos*
#
# ![image.png](data:image/png;base64,...)

# %%
# Realiza as operações de leitura

somente_leitura = open('arquivos_aulas/somente_leitura.txt', 'r')
somente_leitura.close()

# %%
somente_leitura
# Out:
# <_io.TextIOWrapper name='arquivos_aulas/somente_leitura.txt' mode='r' encoding='UTF-8'>

# %%
# Realiza as operações de escrita

arquivo_valores = open('arquivos_aulas/valores.txt', 'w')
arquivo_valores.close()

# %%
arquivo_valores
# Out:
# <_io.TextIOWrapper name='arquivos_aulas/valores.txt' mode='w' encoding='UTF-8'>

# %%
# Realiza as operações de escrita se arquivo já existir, senão retorna erro

arquivo_valores_novo = open('arquivos_aulas/valores.txt', 'x')
arquivo_valores_novo.close()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-23-feef7e31f730> in <module>
#       1 # Realiza as operações de escrita se arquivo já existir, senão retorna erro
#       2
# ----> 3 arquivo_valores_novo = open('arquivos_aulas/valores.txt', 'x')
#       4 arquivo_valores_novo.close()
#
# FileExistsError: [Errno 17] File exists: 'arquivos_aulas/valores.txt'

# %%
arquivo_valores_novo = open('arquivos_aulas/valores_2.txt', 'x')
arquivo_valores_novo.close()

# %%
arquivo_valores_novo
# Out:
# <_io.TextIOWrapper name='arquivos_aulas/valores_2.txt' mode='x' encoding='UTF-8'>

# %%
# Adiciona as operações de escrita abaixo de escrita já existente no arquivo

arquivo_valores = open('arquivos_aulas/valores.txt', 'a')
arquivo_valores.close()

# %%
arquivo_valores
# Out:
# <_io.TextIOWrapper name='arquivos_aulas/valores.txt' mode='a' encoding='UTF-8'>
