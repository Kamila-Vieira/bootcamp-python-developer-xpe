# %% [markdown]
# Funções em Python

# %%
# define as listas com os números a serem somados 
l1 = [1, 2, 3, 4, 5] 
l2 = [3, 1, 5, 9, 0, 8, 2, 3, 4] 
l3 = [12, 43, 23, 12, 789] 

# itera sobre cada lista e soma seus elementos 
soma_l1 = 0 
for item in l1: 
    soma_l1 = soma_l1 + item 
    
soma_l2 = 0
for item in l2: 
    soma_l2 = soma_l2 + item 
    
soma_l3 = 0 
for item in l3: 
    soma_l3 = soma_l3 + item 
    
# exibe os resultados 
print(f'Resultado: l1={soma_l1}, l2={soma_l2}, l3={soma_l3}')
# Out:
# Resultado: l1=15, l2=35, l3=879

# %%
# declaraca a função que soma os elementos da lista 
def soma_lista(lista): 
    soma = 0 
    for item in lista: 
        soma = soma + item 
    return soma 

# chama a função para cada lista 
soma_l1 = soma_lista(l1) 
soma_l2 = soma_lista(l2) 
soma_l3 = soma_lista(l3) 
print(f'Resultado: l1={soma_l1}, l2={soma_l2}, l3={soma_l3}')
# Out:
# Resultado: l1=15, l2=35, l3=879

# %%
# declaraca a função que multiplica os elementos da lista 
def multiplica_lista(lista): 
    resultado = 1 
    for item in lista: 
        resultado = resultado * item 
    return resultado 

# chama a função para cada lista 
multiplica_l1 = multiplica_lista(l1) 
multiplica_l2 = multiplica_lista(l2) 
multiplica_l3 = multiplica_lista(l3) 
print(f'Resultado: l1={multiplica_l1}, l2={multiplica_l2}, l3={multiplica_l3}')
# Out:
# Resultado: l1=120, l2=0, l3=112366224
