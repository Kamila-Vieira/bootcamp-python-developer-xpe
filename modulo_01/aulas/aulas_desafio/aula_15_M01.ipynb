# %% [markdown]
# Dicionários

# %%
# Dicionário onde as chaves são do tipo string 
d1 = {'nome': 'Antônio', 'idade': 36, 'sexo': 'masculino'} 
print(d1) 
# Dicionário onde as chaves são do tipo inteiro 
d2 = {2: 'dois', 1: 'um', 4: 'quatro', 3: 'três', 0: 'zero'} 
print(d2) 
# Dicionário com chaves de tipos mistos 
d3 = {2: 'a', 5.44: True, 'key': None}
print(d3) 
# Dicionário vazio 
d4 = {} 
print(d4)
# Out:
# {'nome': 'Antônio', 'idade': 36, 'sexo': 'masculino'}
# {2: 'dois', 1: 'um', 4: 'quatro', 3: 'três', 0: 'zero'}
# {2: 'a', 5.44: True, 'key': None}
# {}

# %%
# Acesso aos elementos 
print(d2[0]) 
print(d2[2]) 
print(f'Meu nome é {d1["nome"]} e tenho {d1["idade"]} anos')
# Out:
# zero
# dois
# Meu nome é Antônio e tenho 36 anos

# %%
# Acesso por meio do operador [] 
print(d1['endereço'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-7b7f6ab58752> in <module>
#       1 # Acesso por meio do operador []
# ----> 2 print(d1['endereço'])
#
# KeyError: 'endereço'

# %%
# Acesso por meio do método get() 
print(d1.get('endereço'))
# Out:
# None

# %%
# Atualização do valor da chave 'nome' 
d1['nome'] = 'Antônio Carlos' 
print(d1) 
# Adição da chave 'endereço' 
d1['endereço'] = 'Rua 123' 
print(d1)
# Out:
# {'nome': 'Antônio Carlos', 'idade': 36, 'sexo': 'masculino'}
# {'nome': 'Antônio Carlos', 'idade': 36, 'sexo': 'masculino', 'endereço': 'Rua 123'}

# %% [markdown]
# Operações com Dicionários

# %% [markdown]
# - As funções min() e max() continuam retornando o mínimo e o máximo, respectivamente. Entretanto, a operação é realizada somente nas chaves da estrutura, ignorando os seus valores.
#
# - Os operadores de filiação in e not in também operam sobre as chaves, e não sobre os valores.
#
# - O método pop(key) remove o elemento com a chave key. Para remover um elemento arbitrário existe o método popitem().

# %%
# Encontra a maior e menor chave 
print('Maior e menor chave:', max(d2), min(d2)) # Chaves como números
print('Maior e menor chave:', max(d1), min(d1)) # Chaves como strings
# Out:
# Maior e menor chave: 4 0
# Maior e menor chave: sexo idade

# %%
# Adiciona elementos de um outro dicionario 
d2.update({'cinco': 5, 'seis': 6}) 
print(d2)
# Out:
# {2: 'dois', 1: 'um', 4: 'quatro', 3: 'três', 0: 'zero', 'cinco': 5, 'seis': 6}

# %%
# As funcões min() e max() não funcionam com chaves heterogêneas (números e strings)
print('Maior e menor chave:', max(d2), min(d2)) # Chaves como números e strings
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-b7c2456cefaa> in <module>
#       1 # As funcões min() e max() não funcionam com chaves heterogêneas (números e strings)
# ----> 2 print('Maior e menor chave:', max(d2), min(d2)) # Chaves como números e strings
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
# Verifica se o dicionário possui as seguintes chaves 
print("A chave 'dois' está no dicionário?", 'dois' in d2) 
print("A chave 'cinco' não está no dicionário?", 'cinco' in d2)
print("A chave 'cinco' não está no dicionário?", 'cinco' not in d2)
# Out:
# A chave 'dois' está no dicionário? False
# A chave 'cinco' não está no dicionário? True
# A chave 'cinco' não está no dicionário? False

# %%
# Remove o elemento com chave 'zero' 
d2.pop('zero') 
print(d2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-984a247adc39> in <module>
#       1 # Remove o elemento com chave 'zero'
# ----> 2 d2.pop('zero')
#       3 print(d2)
#
# KeyError: 'zero'

# %%
# Adiciona o elemento com chave 'zero'
d2.update({'zero': 0}) 
print(d2)
# Out:
# {2: 'dois', 1: 'um', 4: 'quatro', 3: 'três', 0: 'zero', 'cinco': 5, 'seis': 6, 'zero': 0}

# %%
# Remove o elemento com chave 'zero' 
d2.pop('zero') 
print(d2)
# Out:
# {2: 'dois', 1: 'um', 4: 'quatro', 3: 'três', 0: 'zero', 'cinco': 5, 'seis': 6}

# %% [markdown]
# Iteração de Dicionários

# %%
# Cria o dicionário 
d1 = {'zero': 0, 'um': 1, 'dois': 2, 'três': 3, 'quatro': 4} 

# Itera sobre as chaves 
for key in d1: 
    print(f"{key}: {d1[key]}")
    if key == 'três': 
        print('Chave três encontrada!') 

for key in d1.keys():
    if key == 'quatro': 
        print('Chave quatro encontrada!')
        break
# Out:
# zero: 0
# um: 1
# dois: 2
# três: 3
# Chave três encontrada!
# quatro: 4
# Chave quatro encontrada!

# %%
# Itera sobre os valores 
soma = 0 
for value in d1.values(): 
    soma = soma + value 
print('Soma dos valores do dicionário:', soma) 

# Itera sobre os itens  
for key, value in d1.items(): 
    print(key, value)
# Out:
# Soma dos valores do dicionário: 10
# zero 0
# um 1
# dois 2
# três 3
# quatro 4

# %%
list(d1.values())
# Out:
# [0, 1, 2, 3, 4]

# %%
list(d1.items()) # lista de tuplas com chave e valor
# Out:
# [('zero', 0), ('um', 1), ('dois', 2), ('três', 3), ('quatro', 4)]

# %%
dic = {}

# %%
dic.update({[0, 1, 2]: 'Chave de lista'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-d8b3441f759a> in <module>
# ----> 1 dic.update({[0, 1, 2]: 'Chave de lista'})
#
# TypeError: unhashable type: 'list'

# %%
dic.update({(0, 1, 2): 'Chave de tupla'})
print(dic)
print(dic[(0, 1, 2)])
# Out:
# {(0, 1, 2): 'Chave de tupla'}
# Chave de tupla
