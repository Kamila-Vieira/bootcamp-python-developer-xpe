# %% [markdown]
# Instalação de Novos Módulos
#
# https://packaging.python.org/en/latest/tutorials/packaging-projects/
#
# ``pip install <pacote>``

# %% [markdown]
# Um pacote muito utilizado pelos cientistas de dados é o pandas, que é uma biblioteca para manipulação e análise de dados tabulares. Podemos instalar a versão mais recente do pacote da seguinte forma:

# %%
# !ls
# Out:
# sample_data

# %%
# !pip install colorama
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from colorama import Fore, Back, Style
print('Texto normal')

print(Fore.BLUE + 'Texto azul')
print('Texto azul novamente')

print(Back.BLUE + Fore.WHITE + 'Texto branco com fundo azul')
print('Texto branco com fundo azul novamente')

print(Style.RESET_ALL + 'Texto normal novamente')
# Out:
# Texto normal
# Texto azul
# Texto azul novamente
# Texto branco com fundo azul
# Texto branco com fundo azul novamente
# Texto normal novamente

# %%
# !pip install colorama==0.4.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import colorama

colorama.__version__
# Out:
# '0.4.6'

# %%
from colorama import Fore, Back, Style
print('Texto normal')

print(Fore.BLUE + 'Texto azul')
print('Texto azul novamente')

print(Back.BLUE + Fore.WHITE + 'Texto branco com fundo azul')
print('Texto branco com fundo azul novamente')

print(Style.RESET_ALL + 'Texto normal novamente')
# Out:
# Texto normal
# Texto azul
# Texto azul novamente
# Texto branco com fundo azul
# Texto branco com fundo azul novamente
# Texto normal novamente

# %%
# !pip install --upgrade colorama
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
