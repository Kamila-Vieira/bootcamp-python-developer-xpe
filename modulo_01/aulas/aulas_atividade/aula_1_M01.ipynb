# %%
nome = 'Antônio Carlos' 
print('Olá', nome, 'seja bem-vindo!')
# Out:
# Olá Antônio Carlos seja bem-vindo!

# %%
pessoa = 'Kamila'
print('Olá', pessoa)
# Out:
# Olá Kamila

# %%
numero = 1
numero + 3
numero + 100
# Out:
# 101
